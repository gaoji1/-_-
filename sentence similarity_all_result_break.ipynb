# %%
# -*- coding: utf-8 -*-
"""包导入"""
from simhash import Simhash
import jieba
import jieba.posseg as pseg
from jieba import analyse
import numpy as np
import os
import matplotlib.pyplot as plt 
import matplotlib as mpl
import json
from math import log
import re
import datetime
import logging

# %%
"""文本相似度计算类"""
class TextSimilarity(object):
    
    def __init__(self):
        '''
        初始化类，修改了原来的初始化函数，不加文件初始化参数，空初始化。
        '''
        str_a = ''
        str_b = ''
        
        self.str_a = str_a
        self.str_b = str_b
            
    #get LCS(longest common subsquence),DP
    def lcs(self,str_a, str_b):
        lensum = float(len(str_a) + len(str_b))
        #得到一个二维的数组，类似用dp[lena+1][lenb+1],并且初始化为0
        lengths = [[0 for j in range(len(str_b)+1)] for i in range(len(str_a)+1)]

        #enumerate(a)函数： 得到下标i和a[i]
        for i, x in enumerate(str_a):
            for j, y in enumerate(str_b):
                if x == y:
                    lengths[i+1][j+1] = lengths[i][j] + 1
                else:
                    lengths[i+1][j+1] = max(lengths[i+1][j], lengths[i][j+1])

        #到这里已经得到最长的子序列的长度，下面从这个矩阵中就是得到最长子序列
        result = ""
        x, y = len(str_a), len(str_b)
        while x != 0 and y != 0:
            #证明最后一个字符肯定没有用到
            if lengths[x][y] == lengths[x-1][y]:
                x -= 1
            elif lengths[x][y] == lengths[x][y-1]:
                y -= 1
            else: #用到的从后向前的当前一个字符
                assert str_a[x-1] == str_b[y-1] #后面语句为真，类似于if(a[x-1]==b[y-1]),执行后条件下的语句
                result = str_a[x-1] + result #注意这一句，这是一个从后向前的过程
                x -= 1
                y -= 1
                
                #和上面的代码类似
                #if str_a[x-1] == str_b[y-1]:
                #    result = str_a[x-1] + result #注意这一句，这是一个从后向前的过程
                #    x -= 1
                #    y -= 1
        longestdist = lengths[len(str_a)][len(str_b)]
        ratio = longestdist/min(len(str_a),len(str_b))
        #return {'longestdistance':longestdist, 'ratio':ratio, 'result':result}
        return ratio
        
    
    def minimumEditDistance(self,str_a,str_b):
        '''
        最小编辑距离，只有三种操作方式 替换、插入、删除
        '''
        lensum = float(len(str_a) + len(str_b))
        if len(str_a) > len(str_b): #得到最短长度的字符串
            str_a,str_b = str_b,str_a
        distances = range(len(str_a) + 1) #设置默认值
        for index2,char2 in enumerate(str_b): #str_b > str_a
            newDistances = [index2+1] #设置新的距离，用来标记
            for index1,char1 in enumerate(str_a):
                if char1 == char2: #如果相等，证明在下标index1出不用进行操作变换，最小距离跟前一个保持不变，
                    newDistances.append(distances[index1])
                else: #得到最小的变化数，
                    newDistances.append(1 + min((distances[index1],   #删除
                                                 distances[index1+1], #插入
                                                 newDistances[-1])))  #变换
            distances = newDistances #更新最小编辑距离

        mindist = distances[-1]
        ratio = (lensum - mindist)/lensum
        #return {'distance':mindist, 'ratio':ratio}
        return ratio

    def levenshteinDistance(self,str1, str2):
        '''
        编辑距离——莱文斯坦距离,计算文本的相似度
        '''
        m = len(str1)
        n = len(str2)
        lensum = float(m + n)
        d = []           
        for i in range(m+1):
            d.append([i])        
        del d[0][0]    
        for j in range(n+1):
            d[0].append(j)       
        for j in range(1,n+1):
            for i in range(1,m+1):
                if str1[i-1] == str2[j-1]:
                    d[i].insert(j,d[i-1][j-1])           
                else:
                    minimum = min(d[i-1][j]+1, d[i][j-1]+1, d[i-1][j-1]+2)         
                    d[i].insert(j, minimum)
        ldist = d[-1][-1]
        ratio = (lensum - ldist)/lensum
        #return {'distance':ldist, 'ratio':ratio}
        return ratio
    
    @classmethod
    def splitWords(self,str_a):
        '''
        接受一个字符串作为参数，返回分词后的结果字符串(空格隔开)和集合类型
        '''
        wordsa=pseg.cut(str_a)
        cuta = ""
        seta = set()
        for key in wordsa:
            #print(key.word,key.flag)
            cuta += key.word + " "
            seta.add(key.word)
        
        return [cuta, seta]
    
    def JaccardSim(self,str_a,str_b):
        '''
        Jaccard相似性系数
        计算sa和sb的相似度 len（sa & sb）/ len（sa | sb）
        '''
        seta = self.splitWords(str_a)[1]
        setb = self.splitWords(str_b)[1]
        
        sa_sb = 1.0 * len(seta & setb) / len(seta | setb)
        
        return sa_sb
    
    
    def countIDF(self,text,topK):
        '''
        text:字符串，topK根据TF-IDF得到前topk个关键词的词频，用于计算相似度
        return 词频vector
        '''
        tfidf = analyse.extract_tags

        cipin = {} #统计分词后的词频

        fenci = jieba.cut(text)

        #记录每个词频的频率
        for word in fenci:
            if word not in cipin.keys():
                cipin[word] = 0
            cipin[word] += 1

        # 基于tfidf算法抽取前10个关键词，包含每个词项的权重
        keywords = tfidf(text,topK,withWeight=True)

        ans = []
        # keywords.count(keyword)得到keyword的词频
        # help(tfidf)
        # 输出抽取出的关键词
        for keyword in keywords:
            #print(keyword ," ",cipin[keyword[0]])
            ans.append(cipin[keyword[0]]) #得到前topk频繁词项的词频

        return ans
    @staticmethod
    def cos_sim(a,b):
        a = np.array(a)
        b = np.array(b)
        
        #return {"文本的余弦相似度:":np.sum(a*b) / (np.sqrt(np.sum(a ** 2)) * np.sqrt(np.sum(b ** 2)))}
        return np.sum(a*b) / (np.sqrt(np.sum(a ** 2)) * np.sqrt(np.sum(b ** 2)))
    @staticmethod
    def eucl_sim(a,b):
        a = np.array(a)
        b = np.array(b)
        #print(a,b)
        #print(np.sqrt((np.sum(a-b)**2)))
        #return {"文本的欧几里德相似度:":1/(1+np.sqrt((np.sum(a-b)**2)))}
        return 1/(1+np.sqrt((np.sum(a-b)**2)))
    @staticmethod
    def pers_sim(a,b):
        a = np.array(a)
        b = np.array(b)

        a = a - np.average(a)
        b = b - np.average(b)

        #print(a,b)
        #return {"文本的皮尔森相似度:":np.sum(a*b) / (np.sqrt(np.sum(a ** 2)) * np.sqrt(np.sum(b ** 2)))}
        return np.sum(a*b) / (np.sqrt(np.sum(a ** 2)) * np.sqrt(np.sum(b ** 2)))

    def splitWordSimlaryty(self,str_a,str_b,topK = 20,sim =cos_sim):
        '''
        基于分词求相似度，默认使用cos_sim 余弦相似度,默认使用前20个最频繁词项进行计算
        '''
        #得到前topK个最频繁词项的字频向量
        vec_a = self.countIDF(str_a,topK)
        vec_b = self.countIDF(str_b,topK)
        
        return sim(vec_a,vec_b)
        
    @staticmethod
    def string_hash(self,source):  #局部哈希算法的实现
        if source == "":  
            return 0  
        else:  
            #ord()函数 return 字符的Unicode数值
            x = ord(source[0]) << 7  
            m = 1000003  #设置一个大的素数
            mask = 2 ** 128 - 1  #key值
            for c in source:  #对每一个字符基于前面计算hash
                x = ((x * m) ^ ord(c)) & mask  

            x ^= len(source) # 
            if x == -1:  #证明超过精度
                x = -2  
            x = bin(x).replace('0b', '').zfill(64)[-64:]  
            #print(source,x)  

        return str(x)
    
    
    def simhash(self,str_a,str_b):
        '''
        使用simhash计算相似度
        '''
        pass

# %%
"""具体逻辑"""
def isJson(jsonstr):
    """判断是否是json"""
    try:
        a = json.loads(jsonstr)
        return True
    except:
        return False
    
with open("all_result_break.json",'r',encoding="utf8") as load_f:  
    xianbingshi = []
    for i in range(100000):
        #准备工作
        line = load_f.readline()
        if not line:
            break
        if not isJson(line):
            continue;
        json_to_dic = json.loads(line)
        
        #存储现病史字符串
        if "subject_name" not in json_to_dic:
            continue
        if "呼吸" not in json_to_dic["subject_name"]:
            continue
        if "xianbingshi" not in json_to_dic:
            continue
        temp_xianbingshi = json_to_dic["xianbingshi"]
        xianbingshi.append(temp_xianbingshi)
    
    #计算相似度,打印相似度较大的句子
    text_similarity_manager = TextSimilarity()
    print(xianbingshi[2])
    print("-"*100)
#     similarity_JaccardSim = []
#     similarity_minimumEditDistance = []
    for index,item in enumerate(xianbingshi):
        temp_similarity_JaccardSim = text_similarity_manager.JaccardSim(xianbingshi[2],item)
        temp_similarity_minimumEditDistance = text_similarity_manager.minimumEditDistance(xianbingshi[2],item)
        if temp_similarity_JaccardSim>=0.3 and temp_similarity_JaccardSim!=1.0:
            print(item)
            print("JaccardSim",":",temp_similarity_JaccardSim)
            print("minimumEditDistance",":",temp_similarity_minimumEditDistance)
            print("simhash_distance",":",Simhash(xianbingshi[2]).distance(Simhash(item)))
#             similarity_JaccardSim.append(temp_similarity_JaccardSim)
#             similarity_minimumEditDistance.append(temp_similarity_minimumEditDistance)
            print("-"*100)
#     plt.scatter(similarity_JaccardSim,similarity_minimumEditDistance)
#     plt.show()
    load_f.close()
# Out:
# 患儿1周前无诱因下发热，热峰39.0℃，无咳嗽流涕，无吐泻，当地诊所予静脉输液3天，发烧间隔稍有延长，于人民就诊，予静滴头孢呋辛1天，体温仍有反复升高，精神欠佳，发热时有头痛，无呕吐，热退后无头痛，昨日于我院就诊，查血常规白细胞12.09×109/L，中性粒细胞%77.3%，静滴头孢唑肟、补液1次，拟“发热精神差”入院。病程中，患儿精神进食差，睡眠一般，大小便正常。
# ----------------------------------------------------------------------------------------------------
# 患儿1周前在无明显诱因下出现发热，最高体温达39.5，偶有咳嗽，咳痰，呈白色粘痰，无腹泻、呕吐，自行服用“头孢克肟、小葵花颗粒”3天，患儿体温正常，咳嗽咳痰减轻，2天前早晨患儿出现头痛伴有呕吐，呕吐物为胃内容物，进食差，无腹泻，伴发热，精神差，就诊于省立儿童医院，血检提示血象正常，中性粒细胞比例升高，予静脉用药“喜炎平、奥美拉唑”1次，患儿仍有发热，呕吐，昨日就诊于我院门诊，予以、补液等治疗后，患儿呕吐消失，体温正常，进食可，门诊拟“发热伴呕吐待查”，病程中患儿精神差，进食差，睡眠可，大小便减少。
# JaccardSim : 0.33064516129032256
# minimumEditDistance : 0.5609195402298851
# simhash_distance : 32
# ----------------------------------------------------------------------------------------------------
# 患儿2周前无明显诱因下发热，最高达38.5℃，每次晚上发热1次，具体不清，自行可退热，无咳嗽流涕，无鼻塞，近2天再次发热，于就诊，查血常规白细胞15.7×109/L，血红蛋白72g/L，血小板45×109/L，中性粒细胞(N)%4.9%，淋巴细胞比率%84.70%，遂来我院就诊，查血常规白细胞12.45×109/L，血红蛋白63g/L，血小板51×109/L，中性粒细胞(N)%5.5%，淋巴细胞比率%85.5%，拟“呼吸道感染三系减少原因待查”收住我科。病程中，患儿精神睡眠可，进食一般，大小便正常，近期体重无明显减轻。
# JaccardSim : 0.3089430894308943
# minimumEditDistance : 0.5986547085201793
# simhash_distance : 29
# ----------------------------------------------------------------------------------------------------
# 患儿4天前无明显诱因下发热，热峰39.4℃，每日发热1-2次，口服退热药体温可降至正常，开始有呕吐，共2次，为胃内容物，偶咳1-2声，无明显咳痰，于滨湖医院就诊，查血常规白细胞15.34×109/L，中性粒细胞%82.7%，CRP87.89mg/L，予阿奇霉素口服2天，静滴美洛西林、炎虎宁3次，仍有反复高热，1天前有头痛，为间歇性，不伴呕吐，为进一步诊疗，今来我院，门诊查血常规，拟“呼吸感染败血症”收住我科。病程中，患儿精神一般，睡眠、进食欠佳，有腹痛，为阵发性，大便1天未解，小便正常。
# JaccardSim : 0.359375
# minimumEditDistance : 0.5604651162790698
# simhash_distance : 25
# ----------------------------------------------------------------------------------------------------
# 患儿3天前无明显诱因下出现发热，体温38.2℃，伴有轻声咳嗽，无恶心、呕吐，无腹痛、腹泻，来我院就诊，门诊考虑扁桃体炎，给予头孢呋辛、、地塞米松输液1天后，体温仍旧波动在38.5℃-39℃之间，昨日再次来我院就诊，门诊血常规：白细胞(WBC)10.5×109/L，血红蛋白(Hb)110g/L，血小板(PLT)194×109/L，中性粒细胞(N)71.00%。CRP191mg/L给予输液头孢唑肟、、阿奇霉素后，仍有发热，最高体温39℃，无咳嗽、咳痰，无流涕，为求进一步诊治，门诊拟“化脓性扁桃体炎”收住我科，病程中，精神可，饮食可，二便正常，体重正常；
# JaccardSim : 0.32061068702290074
# minimumEditDistance : 0.5422993492407809
# simhash_distance : 32
# ----------------------------------------------------------------------------------------------------
# 患儿3天前在无明显诱因下出现手、臀部皮疹，部分为疱疹，无发热，无惊跳、肢体抖动，就诊我院门诊，门诊血常规提示：白细胞(WBC)7.88×109/L，血红蛋白(Hb)136g/L，血小板(PLT)310×109/L，中性粒细胞(N)36.9%，予以“利巴韦林气雾剂、头孢克肟”口服治疗1天，2天前出现发热，最高体温38.6℃，无惊跳、无肢体抖动、无抽搐，再次就诊于我院门诊，予以“利巴韦林、头孢西丁”输液治疗2天，仍有发热，伴惊跳明显，为求进一步诊治，收住入院。病程中精神、反应尚可，纳一般，呕吐2次，二便正常。
# JaccardSim : 0.30708661417322836
# minimumEditDistance : 0.5079726651480638
# simhash_distance : 38
# ----------------------------------------------------------------------------------------------------
# 患儿于3天前接触“发热”家人（哥哥）后出现发热，初体温41.6℃（耳温枪测得），伴有寒战，偶有流涕，无咳嗽、气喘，无呕吐、腹泻，无抽搐，初家长予退热药口服处理，次日就诊我院门诊，查血常规提示：WBC28.5×109/L，N73.00%，予“头孢唑肟、喜炎平”输液2天，体温仍有反复，今门诊复查血常规提示：WBC19.2×109/L，N75.70%，CRP196.3mg/L，为求进一步诊治，门诊拟“呼吸道感染，败血症”收住我科，病程中患儿热退精神可，前天饮水后喷射性呕吐1次，食欲欠佳，大小便基本正常。
# JaccardSim : 0.3208955223880597
# minimumEditDistance : 0.5448275862068965
# simhash_distance : 32
# ----------------------------------------------------------------------------------------------------
# 患儿于4天前无明显诱因下出现发热，体温最高39.4℃，无咳嗽，无呕吐，无抽搐，在我科门诊查血示“白细胞4.98×109/L，血小板99×109/L，中性粒细胞74.01%，常规CRP66.01mg/L”，予输液治疗2天（头孢西丁、喜炎平），仍发热，体温波动在38.5℃-39.0℃之间；昨日上午患儿出现恶心感，呕吐2次，非喷射状，吐出胃内容物、量不多、不含胆汁及咖啡样物，伴腹痛，头痛不明显；今日凌晨3点钟睡眠中出现头痛明显，前额部痛，伴有搏动感，无呕吐，体温正常，遂再次至我院门诊，门诊予“头孢唑肟、阿糖腺苷”输液治疗后，拟“中枢神经系统感染可能”收住病房。病程中患儿精神反应一般，无咳嗽，无皮疹，食欲差，睡眠欠佳，大小便尚可。
# JaccardSim : 0.30666666666666664
# minimumEditDistance : 0.501002004008016
# simhash_distance : 30
# ----------------------------------------------------------------------------------------------------
# 患儿2天前无明显诱因下发热，热峰39.5℃，无流涕，偶有咳嗽，精神进食可，今日于我院就诊，查血常规：白细胞13.23×109/L，中性粒细胞%54.2%。常规CRP45.79mg/，予磷霉素、地塞米松静滴1次，并拟“呼吸道感染”收住我科。病程中，患儿精神一般，精神进食可，大小便正常。
# JaccardSim : 0.41237113402061853
# minimumEditDistance : 0.6134969325153374
# simhash_distance : 28
# ----------------------------------------------------------------------------------------------------
# 患儿三天前无明显诱因下出现发热，最高体温39℃，精神差，偶伴睡眠时打惊，无咳嗽、流涕、吐泻，昨日就诊于我院门诊，查血象高，留院观察，予“头孢呋辛、利巴韦林、地塞米松”等对症支持治疗，患儿体温下降，精神好转，偶有打惊，昨夜间呕吐2次，今日再次就诊于我院门诊，门诊拟“疱疹性咽峡炎”收住入院，病程中，患儿热退精神可，纳差，睡眠一般，二便正常。
# JaccardSim : 0.3185840707964602
# minimumEditDistance : 0.5807365439093485
# simhash_distance : 29
# ----------------------------------------------------------------------------------------------------
# 患儿1周前无明显诱因下出现发热，体温最高39.2℃，无明显咳嗽咳痰，就诊当地社区门诊静脉滴注治疗4天，体温正常2天，3天前晚上患儿再次出现发热，体温最高42℃，偶有咳嗽，不剧，伴喉中痰感，无皮疹、抽搐，予口服退热药后渐至正常，仍有反复，昨日体温最高40℃，就诊我院门诊查血常规：白细胞21.88×109/L，中性粒细胞63.7%；CRP＞200mg/L。予头孢呋辛抗感染，为求进一步治疗拟“败血症”收住我科，病程中热退时精神尚可，饮食尚可，二便未见明显异常。
# JaccardSim : 0.336
# minimumEditDistance : 0.612590799031477
# simhash_distance : 33
# ----------------------------------------------------------------------------------------------------
# 患儿5天前无明显诱因下咳嗽，阵发性咳4-5声，早晚较重，有痰，伴有喘息，开始无发热，家长予口服“头孢”2天，诊所静滴药物1天（具体不详），咳嗽仍较剧，无咳吐，3天前发热，热峰接近40℃，于我院就诊，予“头孢西丁、沐舒坦”静滴2天，仍有反复高热，咳嗽加重，门诊拟“呼吸道感染”收住我科。病程中，患儿精神进食欠佳，无呕吐，大小便正常。
# JaccardSim : 0.30701754385964913
# minimumEditDistance : 0.5988538681948424
# simhash_distance : 33
# ----------------------------------------------------------------------------------------------------
# 患儿约2周余前无明显诱因下出现咳嗽，为阵发性连声咳嗽，开始夜间明显，有痰但咳不出，曾就诊于我院门诊，予“阿奇霉素、易坦静”口服3天，患儿咳嗽无好转，改为“酮替芬”口服及雾化治疗2天，患儿咳嗽好转，白天偶有轻咳。昨日始患儿出现发热，体温最高达40℃，伴呕吐1-2次，为胃内容物，非喷射性，再次就诊于我院门诊，查血常规示白细胞23.2×109/L，中性粒细胞(N)64.70%，CRP12.68mg/L，予“头孢唑肟，阿糖腺苷”静滴2天。患儿今晨热退，但仍呕吐2次，为胃内容物，门诊拟"呼吸道感染、败血症？"收住。病程中患儿无皮疹，进食减少，精神可，睡眠可，两便正常。
# JaccardSim : 0.3263888888888889
# minimumEditDistance : 0.555793991416309
# simhash_distance : 30
# ----------------------------------------------------------------------------------------------------
# 患儿于今晨无明显诱因下出现发热，体温39℃多，伴有肢体抖动，偶有打惊，呕吐2次，喷射性呕吐胃内容物，量较多，无咳嗽，无腹泻，无皮疹、抽搐，就诊我院，家长诉当时口腔未见明显疱疹，予头孢克肟等口服，体温仍反复，最高40℃，来我院门诊查血常规提示：WBC24.8×109/L，N79.80%，CRP28.7mg/L，遂拟“疱疹性咽峡炎”收住我科，病程中患儿精神尚可，进食一般，大小便正常。
# JaccardSim : 0.304
# minimumEditDistance : 0.6186666666666667
# simhash_distance : 33
# ----------------------------------------------------------------------------------------------------
# 患儿于3天前受凉后出现发热，体温39℃左右，热前有畏寒，热时伴寒战，无皮疹、抽搐，无咳嗽、流涕，家长自行予退热药口服，体温仍反复，最高40.4℃，昨日出现频繁呕吐，进食水后即出现，喷射性呕吐胃内容物，无咖啡样物质，呕吐近10次，今未再出现呕吐，在查血常规提示WBC25.7×109/L，N80.20%，CRP187mg/L，为求进一步诊治，前来我院，门诊拟“败血症”收住我科，病程中患儿精神一般，胃纳欠佳，有一过性腹痛，大小便基本正常。
# JaccardSim : 0.3023255813953488
# minimumEditDistance : 0.5870646766169154
# simhash_distance : 30
# ----------------------------------------------------------------------------------------------------
# 患儿2天前无明显诱因下出现发热，体温最高达39℃，无咳嗽咳痰、无呕吐腹泻、无头痛、无皮疹伴随症状，就诊我科门诊，予以头孢呋辛、利巴输液治疗2天，输液期间仍有发热，体温波动在38.5℃，昨日傍晚患儿体温降至正常，门诊查血常规提示白细胞1.76*10^9/L,中性粒绝对值0.6*10^9/L，门诊拟“呼吸道感染，粒细胞缺乏”收住。病程中，患儿神清，精神饮食可，大小便正常。
# JaccardSim : 0.3076923076923077
# minimumEditDistance : 0.6314363143631436
# simhash_distance : 34
# ----------------------------------------------------------------------------------------------------
# 患儿5天前无诱因下发热，热峰40.2℃，开始每日发热4-5次，有咳嗽，阵发性咳嗽，有痰感，无喘息，早晚较重，于我院就诊，查血常规：白细胞6.98×109/L，中性粒细胞%66.4%。CRP11.65mg/L。超敏CRP＞5.0mg/L，予奥司他口服4天，仍有反复高热，咳嗽加重，无咳吐，再次就诊我院，门诊予磷霉素静滴1次，拟“肺炎”收住我科。病程中，患儿昨日诉右耳疼痛，耳鼻喉诊断“急性中耳炎”，予洛美沙星滴耳，患儿烧退后精神可，睡眠良好，进食欠佳，大小便正常。
# JaccardSim : 0.352
# minimumEditDistance : 0.5518072289156627
# simhash_distance : 23
# ----------------------------------------------------------------------------------------------------
# 患儿3天前无明显诱因下出现发热，最高体温40℃，为不规则热，热前无明显寒战，热退后有汗，伴轻度鼻塞、流涕，无咳嗽，无呕吐、抽搐，无腹痛，我院门诊血常规：白细胞23.03*109/l,中性粒细胞百分比82.3%，CRP127.36mg/L。门诊予以头孢唑肟、美林、匹多莫得等治疗一天，仍有发热，今日我院门诊拟“败血症化脓性扁桃体炎”收住，病程中患儿饮食睡眠一般，二便正常。
# JaccardSim : 0.3247863247863248
# minimumEditDistance : 0.5718157181571816
# simhash_distance : 38
# ----------------------------------------------------------------------------------------------------
# 患儿4天前在无明显诱因下出现发热，最高体温37.7℃，伴双眼睑浮肿，无惊跳、抽搐，无咳嗽，就诊于当地诊所，予以“利巴颗粒”口服治疗1天，仍有发热，就诊于“”，查血常规：白细胞14.2×109/L，血红蛋白(Hb)121g/L，血小板(PLT)130×109/L，中性粒细胞(N)20.4%，淋巴细胞百分比：50.2%，住院治疗4天，予以“、保肝”治疗4天，仍有发热，最高体温39℃，家长自行出院后，就诊于我院门诊，为求进一步诊治收住入院。病程中患儿精神反应尚可，无咳嗽，无流涕、喷嚏，纳可，无呕吐，二便正常。
# JaccardSim : 0.30708661417322836
# minimumEditDistance : 0.541095890410959
# simhash_distance : 37
# ----------------------------------------------------------------------------------------------------

# %%
"""使用simhash的方法计算相似度"""
def isJson(jsonstr):
    """判断是否是json"""
    try:
        a = json.loads(jsonstr)
        return True
    except:
        return False
    
with open("all_result_break.json",'r',encoding="utf8") as load_f:  
    xianbingshi = []
    for i in range(30000):
        #准备工作
        line = load_f.readline()
        if not line:
            break
        if not isJson(line):
            continue;
        json_to_dic = json.loads(line)
        
        #存储现病史字符串
        if "subject_name" not in json_to_dic:
            continue
        if "呼吸" not in json_to_dic["subject_name"]:
            continue
        if "xianbingshi" not in json_to_dic:
            continue
        temp_xianbingshi = json_to_dic["xianbingshi"]
        xianbingshi.append(temp_xianbingshi)
    
    #计算相似度,打印相似度较大的句子
    simhash_list = [] # 里面存储着每一个句子对应的simhash对象
    print("现病史数据个数",":",len(xianbingshi))
    print(datetime.datetime.now())
    for index,item in enumerate(xianbingshi):
        temp_simhash_obj = Simhash(item)
        simhash_list.append(temp_simhash_obj)
    print(datetime.datetime.now())
    for i_x,x in enumerate(simhash_list):
        for i_y,y in enumerate(simhash_list):
            if i_y<=i_x:
                continue
            if(x.distance(y)>=28):
                logging.info("#"*50)
                logging.info(xianbingshi[i_x])
                logging.info(xianbingshi[i_y])
                logging.info(x.distance(y))
                logging.info("-"*50)
    print(datetime.datetime.now())
                
    load_f.close()
# Out:
# 现病史数据个数 : 1634
# 2018-06-27 16:32:19.222858
# 2018-06-27 16:32:26.482752
# 2018-06-27 16:32:49.860203
